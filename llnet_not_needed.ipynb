# %%
from tensorflow.keras import models, layers

# %%
#Load images from a directory in python

#!/usr/bin/python
from os import listdir
from PIL import Image as PImage

def loadImages(path):
    # return array of images

    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        loadedImages.append(img)

    return loadedImages

path = "/Nature_Images_Dataset/"

# your images in an array
imgs = loadImages(path)

for img in imgs:
    # you can show every image
    img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6feffcf7c7e5> in <module>()
#      16
#      17 # your images in an array
# ---> 18 imgs = loadImages(path)
#      19
#      20 for img in imgs:
#
# <ipython-input-2-6feffcf7c7e5> in loadImages(path)
#       5     # return array of images
#       6
# ----> 7     imagesList = listdir(path)
#       8     loadedImages = []
#       9     for image in imagesList:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Nature_Images_Dataset/'

# %%
from sklearn.feature_extraction import image

patches = image.extract_patches_2d(one_image, (17, 17))

# %%
model = models.Sequential()
model.add(layers.Flatten(input_shape=[34,34,3]))
model.add(layers.Dense(2000, activation="sigmoid"))
model.add(layers.Dense(1600, activation="sigmoid"))
model.add(layers.Dense(1200, activation="sigmoid"))
model.add(layers.Dense(1600, activation="sigmoid"))
model.add(layers.Dense(2000, activation="sigmoid"))
model.add(layers.Dense(867, activation="sigmoid"))

# %%
model.compile(optimizer='rmsprop', loss='mse')

model.fit(x_train, y_train, epochs = 200)
